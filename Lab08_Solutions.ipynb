# %%
class BTNode:
  def __init__(self, elem):
    self.elem = elem           # Root, left child, right child
    self.right = None
    self.left = None

# %%
# pre - root Left Right
# in - left root right
# post - left right root

# %%
def inorder(root):   # left, roort, right
  if root == None:
    return

  inorder(root.left)
  print(root.elem, end = ' ')
  inorder(root.right)

# %%
def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None
  p = BTNode(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p


root2 = tree_construction([None, 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', None, None, None, 'I', 'J', None, 'k'])
inorder(root2)
# Out:
# H D B E A I F J C G k

# %% [markdown]
# Task 1

# %%
def convert_mirror(root):
  if root == None:
    return None

  # Swap left and right subtrees
  root.left, root.right = root.right, root.left

  # Recursively convert mirror for left and right subtrees
  convert_mirror(root.left)      # Pass the value in function
  convert_mirror(root.right)     # Pass the value in function

  return root

#DRIVER CODE
root = BTNode(10)
n1 = BTNode(20)
n2 = BTNode(30)
n3 = BTNode(40)
n4 = BTNode(60)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  40 20 60 10 30
print()

root2 = convert_mirror(root)
print('Mirrored Tree Inorder Traversal: ', end = ' ')
inorder(root2) #Mirrored Tree Inorder Traversal:  30 10 60 20 40
# Out:
# Given Tree Inorder Traversal:  40 20 60 10 30
# Mirrored Tree Inorder Traversal:  30 10 60 20 40

# %% [markdown]
# Task 2

# %%
def largest_level(root):
    def first_search(node, level):
        if not node:
            return

        if level not in max_per_level:
            max_per_level[level] = float('-inf')
        max_per_level[level] = max(max_per_level[level], node.elem)

        first_search(node.left, level + 1)
        first_search(node.right, level + 1)

    max_per_level = {}
    first_search(root, 0)
    return max_per_level

#DRIVER CODE
root = tree_construction([None, 4,9,2,3,5,None,7])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  3 9 5 4 2 7
print()
print('Level Wise Largest Value: ', end = ' ')
print(largest_level(root)) #Level Wise Largest Value:  {0: 4, 1: 9, 2: 7}
# Out:
# Given Tree Inorder Traversal:  3 9 5 4 2 7
# Level Wise Largest Value:  {0: 4, 1: 9, 2: 7}

# %% [markdown]
# Task 3

# %%
def inorder_successor(root, x):    # BST - left<root<right   # Get Sorted
    if root is None:
        return None

    if root.elem <= x.elem:
        return inorder_successor(root.right, x)
    else:
        left_candidate = inorder_successor(root.left, x)
        return left_candidate if left_candidate else root

#DRIVER CODE
root = BTNode(20)
n1 = BTNode(8)
n2 = BTNode(22)
n3 = BTNode(4)
n4 = BTNode(12)
n5 = BTNode(10)
n6 = BTNode(14)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n4.left = n5
n4.right = n6

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  4 8 10 12 14 20 22
print()

x = n1
print(f'Inorder successor of node {x.elem}: {inorder_successor(root, x).elem}') #Inorder successor of node 8: 10
# Out:
# Given Tree Inorder Traversal:  4 8 10 12 14 20 22
# Inorder successor of node 8: 10

# %% [markdown]
# Task 4

# %%
def kth_smallest(root, k):
    def inorder_traversal(node):
        nonlocal k
        if node is None or k == 0:
            return None

        result = inorder_traversal(node.left)
        if result is not None:
            return result

        k -= 1
        if k == 0:
            return node

        return inorder_traversal(node.right)

    return inorder_traversal(root)

#DRIVER CODE
root = tree_construction([None, 9,5,11,4,7,None,12,None,None,6,8,None,None,None,None])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root)
print()
k = 4
print(kth_smallest(root,k).elem)   # 7
# Out:
# Given Tree Inorder Traversal:  4 5 6 7 8 9 11 12
# 7
